# %% [markdown]
# # Import Packages and Loading of Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.impute import SimpleImputer
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

df = pd.read_csv('covid.csv')

# %% [markdown]
# # Basic Dataset info and Descriptive Statistics

# %%
print(df.info())

print("Dataset shape:", df.shape)

print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
# None
# Dataset shape: (344, 7)
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# # Data Integrity Checks

# %% [markdown]
# ## Data Interrogation, checking of nulls and duplications

# %%
print(df.isnull().sum())

print(df.duplicated().sum())

for column in ['species', 'island', 'sex']:
    sns.countplot(x=column, data=df)
    plt.title(f'Distribution of {column}')
    plt.show()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64
# 0

# %%
print(df.isnull().sum())
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %% [markdown]
# ## Checking for any unexpected categories in variables

# %%
print(df['species'].unique())
print(df['island'].unique())
print(df['sex'].unique())
# Out:
# ['Adelie' 'Chinstrap' 'Gentoo']
# ['Torgersen' 'Biscoe' 'Dream']
# ['MALE' 'FEMALE' nan '.']

# %% [markdown]
# Portions of our data include null rows and values, especially with respect to categorizing the penguins by sex. Data cleaning is thus necessary to better inform analysis.

# %% [markdown]
# # Data Cleaning and Transformation
# ## Removing Null Values

# %%
print("Before Cleaning:")
print(df.isnull().sum())
print("Dataset shape:", df.shape)

df_cleaned = df.dropna()
print("\nAfter Removing Null Values:")
print(df_cleaned.isnull().sum())
print("Dataset shape after removing null values:", df_cleaned.shape)
# Out:
# Before Cleaning:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64
# Dataset shape: (344, 7)
#
# After Removing Null Values:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64
# Dataset shape after removing null values: (334, 7)

# %% [markdown]
# ## Imputing Missing values
# The other approach is to impute the missing numbers or categories by using Scikit-Learn. Sex can be assumed to be the most frequent, while median values can fill in culmen, flipper length and body mass.

# %%
numerical_columns = ['culmen_length_mm', 'culmen_depth_mm',
                     'flipper_length_mm', 'body_mass_g']
imputer_num = SimpleImputer(strategy='median')
df[numerical_columns] = imputer_num.fit_transform(df[numerical_columns])


categorical_columns = ['species', 'island', 'sex']
imputer_cat = SimpleImputer(strategy='most_frequent')
df[categorical_columns] = imputer_cat.fit_transform(df[categorical_columns])

print("\nAfter Imputing Missing Values:")
print(df.isnull().sum())
print("Dataset shape after imputing missing values:", df.shape)
# Out:
# After Imputing Missing Values:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64
# Dataset shape after imputing missing values: (344, 7)

# %% [markdown]
# # Distribution of Numerical Variables

# %%
for column in ['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
               'body_mass_g']:
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()

# %% [markdown]
# # Correlation Analysis

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df[['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
                'body_mass_g']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Checking for Outliers

# %%
for column in ['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
               'body_mass_g']:
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(df, hue='species')
plt.suptitle('Pair Plot of Numerical Variables by Species', y=1.02)
plt.show()

# %% [markdown]
# # Violin Plots for Numerical Variables by Species

# %%
numerical_columns = ['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']
for column in numerical_columns:
    sns.violinplot(x='species', y=column, data=df)
    plt.title(f'Violin Plot of {column} by Species')
    plt.show()

# %% [markdown]
# # Count Plot for Species Distribution Across Islands

# %%
sns.countplot(x='island', hue='species', data=df)
plt.title('Species Distribution Across Islands')
plt.show()

# %% [markdown]
# # Bar Plots for Average Numerical Values by Species

# %%
for column in numerical_columns:
    sns.barplot(x='species', y=column, data=df, estimator=np.mean)
    plt.title(f'Average {column} by Species')
    plt.show()

# %% [markdown]
# # Bar Plots for Average Numerical Values by Sex

# %%
for column in numerical_columns:
    sns.barplot(x='sex', y=column, data=df, estimator=np.mean)
    plt.title(f'Average {column} by Sex')
    plt.show()

# %%
df['sex']
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3        MALE
# 4      FEMALE
#         ...
# 339      MALE
# 340    FEMALE
# 341      MALE
# 342    FEMALE
# 343      MALE
# Name: sex, Length: 344, dtype: object
